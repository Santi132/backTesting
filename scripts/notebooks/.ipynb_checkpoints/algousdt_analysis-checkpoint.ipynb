# %%
# %matplotlib widget
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import mplfinance as mpf
from pathlib import Path
import backtrader as bt
import plotly.io as pio
import datetime

CRYPTO_DATA_CSV_PATH = Path('~/work/backtesting/data')
ALGOUSDT_CSV_FILE = CRYPTO_DATA_CSV_PATH / 'ALGOUSDT_MinuteBars.csv'

# %%
data_pd = pd.read_csv(ALGOUSDT_CSV_FILE)
data_pd = data_pd.drop(columns=['ignore', 'tb_base_av', 'tb_quote_av', 'quote_av', 'trades', 'close_time'])
data_pd['timestamp'] = data_pd['timestamp'].apply(lambda x: x.split('.')[0])
data_pd.timestamp = pd.to_datetime(data_pd.timestamp, format='%Y-%m-%d %H:%M:%S')
data_pd = data_pd.set_index('timestamp')

data_pd.head()
#data_pd.plot()
# Out:
#                       open   high    low  close      volume
# timestamp
# 2019-06-22 00:00:00  3.400  3.440  2.989  3.150  196437.510
# 2019-06-22 00:01:00  3.150  3.151  3.019  3.039  157708.607
# 2019-06-22 00:02:00  3.030  3.030  2.875  2.952  145305.629
# 2019-06-22 00:03:00  2.952  2.971  2.893  2.950   95730.841
# 2019-06-22 00:04:00  2.950  2.950  2.880  2.900   47611.763

# %%
data_pd.boxplot()
# Out:
# <AxesSubplot:>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
